# %% [markdown]
# # Lab: Math Essentials
#
# Notebook này minh họa một số tính toán Đại số tuyến tính cơ bản và ý tưởng xấp xỉ Đạo hàm trong Giải tích.

# %%
# === Setup Environment ===
import sys, os

if 'google.colab' in sys.modules:
    print("Running on Google Colab...")
elif 'KAGGLE_KERNEL_RUN_TYPE' in os.environ:
    print("Running on Kaggle...")
else:
    print("Running locally...")

# Cố định seed và import
import random, numpy as np
random.seed(42); np.random.seed(42)
import time
import matplotlib.pyplot as plt

# %% [markdown]
# ## Phần 1: Phép nhân Ma Trận
# Kiểm tra quy tắc Shape khi nhân ma trận.

# %%
A = np.array([
    [1, 2],
    [3, 4],
    [5, 6]
]) # Shape (3, 2)

B = np.array([
    [7, 8, 9],
    [10, 11, 12]
]) # Shape (2, 3)

# TODO 1: Tính C = A * B (Matrix Multiplication)
C = ...
print("Ma trận C:\n", C)
print("Shape của C:", C.shape) # Phải là (3, 3)

# %% [markdown]
# ## Phần 2: Xấp Xỉ Đạo Hàm (Numeric Derivative)
# Minh họa ý nghĩa hình học của đạo hàm: Độ dốc của đường tiếp tuyến.

# %%
def f(x):
    return x**2 + 2*x + 1

# Đạo hàm phân tích (Tính tay): f'(x) = 2x + 2
# Tại x = 2.0, f'(2) = 6

x_val = 2.0
h = 1e-4

# TODO 2: Tính đạo hàm xấp xỉ bằng Central Difference
numeric_grad = ...

print(f"Đạo hàm chính xác tại x={x_val}: 6.0")
print(f"Đạo hàm xấp xỉ: {numeric_grad:.4f}")

# %% [markdown]
# ## Phần 3: Thống kê cơ bản
# Tính Mean và Standard Deviation dọc theo các trục.

# %%
# Điểm thi của 5 học sinh (hàng) trong 3 môn (cột)
scores = np.array([
    [8, 7, 9],
    [5, 6, 5],
    [9, 9, 10],
    [7, 8, 7],
    [6, 5, 6]
])

# TODO 3: Tính điểm trung bình của từng môn (dọc theo cột)
mean_scores = ...
print("Điểm TB từng môn:", mean_scores)

# TODO 4: Tính điểm trung bình của từng học sinh (dọc theo hàng)
student_means = ...
print("Điểm TB từng học sinh:", student_means)
