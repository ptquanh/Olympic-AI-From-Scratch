# %%
# === Setup ===
# Runtime: ~5 phút trên Colab T4
# Hardware: CPU ok / Nên dùng GPU
import os, random
import numpy as np
import torch
random.seed(42)
np.random.seed(42)
torch.manual_seed(42)
if torch.cuda.is_available():
    torch.cuda.manual_seed_all(42)

if 'google.colab' in str(get_ipython()):
    print("Running on Google Colab...")
elif 'KAGGLE_KERNEL_RUN_TYPE' in os.environ:
    print("Running on Kaggle...")
else:
    print("Running locally...")

# %% [markdown]
# # So sánh L1 Loss và L2 Loss (MSE)

# %%
import torch.nn as nn

pred = torch.tensor([1.0, 2.0, 3.0])
true = torch.tensor([1.0, 2.0, 10.0]) # Cố tình tạo 1 outlier

l1 = nn.L1Loss()
l2 = nn.MSELoss()
print('L1 Loss (MAE):', l1(pred, true).item())
print('L2 Loss (MSE):', l2(pred, true).item())
