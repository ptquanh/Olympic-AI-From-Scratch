# %%
# === Setup ===
# Runtime: ~5 phút trên Colab T4
# Hardware: Cần GPU (hoặc CPU nếu chạy model nhỏ)
import random, numpy as np
import torch
random.seed(42); np.random.seed(42); torch.manual_seed(42)
# Cẩm nang P08: Cho phép torch, transformers, torchvision

# %% [markdown]
# # Experiments: So sánh số lượng tham số
#
# Hãy xem số lượng tham số cần huấn luyện giảm đi bao nhiêu.

# %%
def count_parameters(model):
    return sum(p.numel() for p in model.parameters() if p.requires_grad)

print(f"Số tham số nếu Full Fine-Tuning: {count_parameters(model):,}")
print(f"Số tham số nếu dùng LoRA: {count_parameters(peft_model):,}")
