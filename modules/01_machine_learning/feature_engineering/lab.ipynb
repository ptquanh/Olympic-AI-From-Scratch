# %%
# === Setup ===
# Runtime: <1m with OAI_FAST_MODE=1
# Hardware: CPU smoke
# Network: none
# Competition-safe: Yes for the declared profile
import os, random, math, re, json, csv, time
from pathlib import Path
import numpy as np
import pandas as pd
FAST_MODE = os.getenv("OAI_FAST_MODE", "0") == "1"
RUNTIME_PROFILE = os.getenv("OAI_RUNTIME_PROFILE", "cpu")
random.seed(42)
np.random.seed(42)
print(f"Runtime profile: {'fast' if FAST_MODE else 'full'}")

# %% [markdown]
# # 🛠 Feature Engineering (Đặc trưng Dữ liệu)

# %% [markdown]
# Lab này sẽ tập trung vào tạo tính năng ngày tháng và mã hóa biến Categorical.

# %%
import pandas as pd
import numpy as np

data = {"Date": ["2023-01-01", "2023-01-02", "2023-01-03"], "City": ["HN", "HCM", "HN"], "Target": [1, 0, 1]}
df = pd.DataFrame(data)

# %%
# 1. Date Features
df["Date"] = pd.to_datetime(df["Date"])
df["Month"] = df["Date"].dt.month
df["DayOfWeek"] = df["Date"].dt.dayofweek
display(df)

# %%
# 2. One-Hot Encoding
df_encoded = pd.get_dummies(df, columns=["City"], drop_first=True)
display(df_encoded)
