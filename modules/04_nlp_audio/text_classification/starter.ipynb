# %%
# === Setup ===
# Runtime: ~10 phút trên Colab T4
# Hardware: Cần GPU (T4 là đủ)
import os, random
import numpy as np
import torch
random.seed(42)
np.random.seed(42)
torch.manual_seed(42)
try:
    if 'google.colab' in str(get_ipython()):
        print('Running on Google Colab...')
except NameError:
    if 'KAGGLE_KERNEL_RUN_TYPE' in os.environ:
        print('Running on Kaggle...')
    else:
        print('Running locally...')

# %% [markdown]
# # Starter Code: Text Classification
# Nhiệm vụ của bạn là hoàn thiện các block TODO để huấn luyện mô hình BERT phân loại bình luận độc hại.

# %%
# TODO 1: Tải dữ liệu
# Bạn có thể dùng bộ dummy data này để code trước pipeline
texts = ['I love this!', 'You are an idiot!', 'This is nice.', 'Shut up!']
labels = [0, 1, 0, 1]

# %%
# TODO 2: Khởi tạo AutoTokenizer
# from transformers import AutoTokenizer
# tokenizer = AutoTokenizer.from_pretrained(...)

# %%
# TODO 3: Viết class Dataset (Xem code_notes.md)

# %%
# TODO 4: Tải mô hình AutoModelForSequenceClassification

# %%
# TODO 5: Viết Training Loop
# Nhớ lấy outputs.loss và gọi backward!
