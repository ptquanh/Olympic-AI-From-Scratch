# %%
# === Setup ===
import os, random
import numpy as np
import torch
random.seed(42)
np.random.seed(42)
torch.manual_seed(42)
if 'KAGGLE_KERNEL_RUN_TYPE' in os.environ:
    print('Running on Kaggle...')
else:
    print('Running locally...')

# %% [markdown]
# # Load Pretrained Stable Diffusion (Giả lập)

# %%
# Cần cài đặt pip install diffusers
# from diffusers import StableDiffusionPipeline
print('Trong bài lab này, chúng ta sẽ xem cách tải model từ HuggingFace.')
